# %% [markdown]
# --------------------------------------------------------------------------------------------
# ## Base Model
# - Using CNN and RNN in a mixing way

# %%
import os, re
from glob import glob
import pickle
import numpy as np
import pandas as pd
from glob import glob
from PIL import Image
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
from nltk.translate.bleu_score import corpus_bleu
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.image import load_img , img_to_array
from tensorflow.keras.applications.vgg16 import VGG16 , preprocess_input
from tensorflow.keras.applications import ResNet152
from tensorflow.keras.applications.densenet import DenseNet201
from tensorflow.keras.layers import Input , Dense , LSTM , Embedding , Dropout , add
from tensorflow.keras.layers import Input, Dense, Dropout, Embedding, LSTM
from tensorflow.keras.models import Model

import time
from datetime import timedelta as td

# %%
import psutil
import GPUtil # Only for Nvidea

# Resources where the training has been made
mem = psutil.virtual_memory()
gpus = GPUtil.getGPUs()
print("CPU cores:", psutil.cpu_count(logical=True))
print('-----------------------------------------')
print(f"Total RAM: {mem.total / (1024**3):.2f} GB")
print(f"Used RAM: {mem.used / (1024**3):.2f} GB")
print(f"Available RAM: {mem.available / (1024**3):.2f} GB")
print('-----------------------------------------')
for gpu in gpus:
    print(f"GPU: {gpu.name}")
    print(f"Total memory: {gpu.memoryTotal}MB")
# Out:
# CPU cores: 8
# -----------------------------------------
# Total RAM: 31.71 GB
# Used RAM: 10.65 GB
# Available RAM: 21.06 GB
# -----------------------------------------
# GPU: NVIDIA GeForce RTX 2060
# Total memory: 6144.0MB

# %%
# Start timer for the training
start_time = time.perf_counter()

# %%
# Paths inside Google cloud
# BUCKET = "weather-description-ml-bucket-20250920-144834"
# resources_path = os.path.join(f"gs://{BUCKET}", "resources")

# Local paths
resources_path = os.path.join('..', '..', 'resources')

path_openAI    = os.path.join(resources_path, 'utils', 'images_weather_description_openAI.csv')
path_ibericam  = os.path.join(resources_path, 'images_ibericam')
path_captions  = os.path.join(resources_path, 'captions.txt')
path_model     = os.path.join(resources_path, 'utils', 'best_model_cnn_lstm.h5')

# %% [markdown]
# ### 1. Generate the mapping for captions in the dataset

# %%
df_openAI   = pd.read_csv(path_openAI)
list_images_ibercam = glob(os.path.join(path_ibericam, '*.jpg'))

# Delete this lines for working with the hole dataset
# df_openAI = df_openAI[df_openAI.path_image.isin(list_images_ibercam)].reset_index()

# %%
df_aux               = df_openAI[['path_image', 'description']]
df_aux               = df_aux.copy()  # Create a full copy to avoid the warning
df_aux['path_image'] = df_aux['path_image'].apply(lambda x: x.split(os.sep)[-1])
df_aux.columns       = ['image', 'caption']

# Get the name of the images
df_aux['image_name'] = df_aux["image"].str.split('.').str[0]

# Cleaning and formating the dataset before applying LSTM
df_aux['caption_mod'] = df_aux["caption"].apply(lambda caption: [f'startseq "{re.sub("[^A-Za-z . -]", "", caption.lower())}" endseq'])

# Creating a dictinary with the name of the photos and the captions
mapping_dic          = dict(zip(df_aux['image_name'], df_aux['caption_mod']))
list_captions        = df_aux['caption_mod'].values
list_captions        = [item[0] for item in list_captions]

# %% [markdown]
# ### 2. Load CNN prebuild models
# - Modify the preloaded models from keras to:
#     - Inputs: mantains the original inputs of the original model
#     - Outputs: Takes the second last layer of the model avoiding the last one to be used later as an input to the LSTM

# %%
##### 16 layer network using 3x3 convolutions image classification #####
model = VGG16()
##### Dense networks with direct connections among all the layers to improve the gradient flow #####
# model = DenseNet201()
##### Residual networks, prevents performance degradation #####
# model = ResNet152()


# model = Model(inputs = model.inputs , outputs = model.layers[-2].output)

desired_output = model.get_layer('fc2').output
model = Model(inputs=model.input, outputs=desired_output)

# %% [markdown]
# ### 3. Transform the images
# - Open the images and adapt it to work with tensorflow

# %%
features = {}
list_images_ibercam = glob(os.path.join(path_ibericam, '*.jpg'))

for index, img_path in enumerate(tqdm(list_images_ibercam)):
    
    # load the image from file in a certain format adapted to the model size
    image = load_img(img_path, target_size= (224, 224))#(model.input.shape[1], model.input.shape[2]))
    
    # convert image pixels to numpy array
    image = img_to_array(image)
    
    # reshape data for model
    image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
    
    # preprocess image for tensorflow
    image = preprocess_input(image)
    
    # extract features
    feature = model.predict(image, verbose=0)

    
    # Get image name
    image_id = os.path.splitext(os.path.basename(img_path))[0]
    
    # store feature
    features[image_id] = feature

# Store the features of the images in a pickle file (for saving time for running multiple experiments)
pickle.dump(features, open(os.path.join(resources_path, 'features.pkl'), 'wb'))
# Out:
#   0%|          | 0/6982 [00:00<?, ?it/s]

# %% [markdown]
# ### 6. Data generator

# %%
def data_generator(data_keys, mapping, features, tokenizer, max_length, vocab_size, batch_size):
    X1, X2, y = list(), list(), list()
    n = 0

    while True:
        for key in data_keys:
            captions = mapping[key]
            for caption in captions:
                seq = tokenizer.texts_to_sequences([caption])[0]
                if len(seq) < 2:
                    continue

                in_seq = seq[:-1]
                out_seq = seq[1:]

                in_seq = pad_sequences([in_seq], maxlen=max_length, padding='post')[0]
                out_seq = pad_sequences([out_seq], maxlen=max_length, padding='post')[0]

                out_seq = to_categorical(out_seq, num_classes=vocab_size)

                X1.append(features[key].reshape(-1))  # asegura dimensión correcta
                X2.append(in_seq)
                y.append(out_seq)

                n += 1
                if n == batch_size:
                    yield ((np.array(X1), np.array(X2)), np.array(y))
                    X1, X2, y = list(), list(), list()
                    n = 0

# %% [markdown]
# ### 4. Tokenizer the text data

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(list_captions)
vocab_size = len(tokenizer.word_index) + 1

# Maximum size of one of the captions
max_length = max(len(caption.split()) for caption in list_captions)

# %% [markdown]
# ### 5. Create LSTM model
# - **shape=(4096,)** - output length of the features from the VGG model
#
# - **Dense** - single dimension linear layer array
#
# - **Dropout()** - used to add regularization to the data, avoiding over fitting & dropping out a fraction of the data from the layers
#
# - **model.compile()** - compilation of the model
#
# - **loss=’sparse_categorical_crossentropy’** - loss function for category outputs
#
# - **optimizer=’adam’** - automatically adjust the learning rate for the model over the no. of epochs
#
# - Model plot shows the concatenation of the inputs and outputs into a single layer
#
# - Feature extraction of image was already done using VGG, no CNN model was needed in this step.

# %%
# Entrada de características de la imagen
inputs_img = Input(shape=(4096,), name='image_input')
img_features = Dropout(0.4)(inputs_img)
img_features = Dense(256, activation='relu')(img_features)

# Entrada de secuencia de texto
inputs_seq = Input(shape=(max_length,), name='sequence_input')
seq_embedding = Embedding(vocab_size, 256, mask_zero=True)(inputs_seq)
seq_embedding = Dropout(0.4)(seq_embedding)

# Inicializar estados del LSTM a partir de características de la imagen
state_h = Dense(256, activation='relu')(img_features)
state_c = Dense(256, activation='relu')(img_features)

# Capa LSTM usando las características de imagen como estado inicial
lstm_out = LSTM(256, return_sequences=True)(seq_embedding, initial_state=[state_h, state_c])

# Capas finales de clasificación
decoder_dense = Dense(256, activation='relu')(lstm_out)
outputs = Dense(vocab_size, activation='softmax')(decoder_dense)

# Definición del modelo
model = Model(inputs=[inputs_img, inputs_seq], outputs=outputs)

# Compilación
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Resumen del modelo
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ image_input (InputLayer)      │ (None, 4096)              │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ sequence_input (InputLayer)   │ (None, 97)                │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout (Dropout)             │ (None, 4096)              │               0 │ image_input[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ embedding (Embedding)         │ (None, 97, 256)           │         229,376 │ sequence_input[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 256)               │       1,048,832 │ dropout[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_1 (Dropout)           │ (None, 97, 256)           │               0 │ embedding[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 256)               │          65,792 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 256)               │          65,792 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm (LSTM)                   │ (None, 97, 256)           │         525,312 │ dropout_1[0][0],           │
# │                               │                           │                 │ dense_1[0][0],             │
# │                               │                           │                 │ dense_2[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_3 (Dense)               │ (None, 97, 256)           │          65,792 │ lstm[0][0]                 │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_4 (Dense)               │ (None, 97, 896)           │         230,272 │ dense_3[0][0]              │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 2,231,168 (8.51 MB)
#  Trainable params: 2,231,168 (8.51 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 5. Prepare data for trainning
# - Train split data

# %%
image_ids = list(mapping_dic.keys())
split = int(len(image_ids) * 0.90)
train = image_ids[:split]
test = image_ids[split:]

# %% [markdown]
# ### 7. Train Model

# %%
epochs = 300
batch_size = 32
steps = len(train) // batch_size

for i in range(epochs):
    print("Epoch", i , " in a total of", epochs)
    # create data generator
    generator = data_generator(train, mapping_dic, features, tokenizer, max_length, vocab_size, batch_size)
    # fit for one epoch
    model.fit(generator, epochs=1, steps_per_epoch=steps, verbose=1)

# Save the best model
model.save(path_model)
# Out:
# Epoch 0  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 22s 203ms/step - accuracy: 0.0531 - loss: 4.9464
# Epoch 1  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 20s 200ms/step - accuracy: 0.2482 - loss: 2.4138
# Epoch 2  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 19s 196ms/step - accuracy: 0.3037 - loss: 1.8346
# Epoch 3  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 19s 198ms/step - accuracy: 0.3261 - loss: 1.6184
# Epoch 4  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 19s 194ms/step - accuracy: 0.3394 - loss: 1.4912
# Epoch 5  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 20s 208ms/step - accuracy: 0.3486 - loss: 1.4031
# Epoch 6  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 20s 199ms/step - accuracy: 0.3558 - loss: 1.3354
# Epoch 7  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 19s 193ms/step - accuracy: 0.3608 - loss: 1.2852
# Epoch 8  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 19s 194ms/step - accuracy: 0.3658 - loss: 1.2433
# Epoch 9  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 20s 201ms/step - accuracy: 0.3700 - loss: 1.2059
# Epoch 10  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 20s 199ms/step - accuracy: 0.3737 - loss: 1.1734
# Epoch 11  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 19s 196ms/step - accuracy: 0.3766 - loss: 1.1459
# Epoch 12  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 19s 197ms/step - accuracy: 0.3795 - loss: 1.1209
# Epoch 13  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 19s 196ms/step - accuracy: 0.3821 - loss: 1.0998
# Epoch 14  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 19s 197ms/step - accuracy: 0.3836 - loss: 1.0807
# Epoch 15  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 19s 197ms/step - accuracy: 0.3863 - loss: 1.0621
# Epoch 16  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 19s 198ms/step - accuracy: 0.3885 - loss: 1.0439
# Epoch 17  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 19s 198ms/step - accuracy: 0.3902 - loss: 1.0293
# Epoch 18  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 19s 197ms/step - accuracy: 0.3925 - loss: 1.0137
# Epoch 19  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 19s 198ms/step - accuracy: 0.3940 - loss: 0.9987
# Epoch 20  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 20s 205ms/step - accuracy: 0.3958 - loss: 0.9867
# Epoch 21  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 21s 214ms/step - accuracy: 0.3972 - loss: 0.9756
# Epoch 22  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 20s 200ms/step - accuracy: 0.3993 - loss: 0.9599
# Epoch 23  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 20s 206ms/step - accuracy: 0.4008 - loss: 0.9489
# Epoch 24  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 19s 197ms/step - accuracy: 0.4023 - loss: 0.9363
# Epoch 25  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 19s 198ms/step - accuracy: 0.4036 - loss: 0.9265
# Epoch 26  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 21s 215ms/step - accuracy: 0.4050 - loss: 0.9160
# Epoch 27  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 23s 234ms/step - accuracy: 0.4065 - loss: 0.9031
# Epoch 28  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 21s 212ms/step - accuracy: 0.4080 - loss: 0.8954
# Epoch 29  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 21s 214ms/step - accuracy: 0.4093 - loss: 0.8846
# Epoch 30  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 21s 217ms/step - accuracy: 0.4106 - loss: 0.8745
# Epoch 31  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 20s 207ms/step - accuracy: 0.4122 - loss: 0.8650
# Epoch 32  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 21s 213ms/step - accuracy: 0.4129 - loss: 0.8577
# Epoch 33  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 20s 204ms/step - accuracy: 0.4142 - loss: 0.8489
# Epoch 34  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 20s 207ms/step - accuracy: 0.4158 - loss: 0.8386
# Epoch 35  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 20s 208ms/step - accuracy: 0.4169 - loss: 0.8303
# Epoch 36  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 21s 210ms/step - accuracy: 0.4177 - loss: 0.8231
# Epoch 37  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 21s 210ms/step - accuracy: 0.4189 - loss: 0.8148
# Epoch 38  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 21s 212ms/step - accuracy: 0.4199 - loss: 0.8094
# Epoch 39  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 21s 211ms/step - accuracy: 0.4207 - loss: 0.8013
# Epoch 40  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 22s 222ms/step - accuracy: 0.4225 - loss: 0.7933
# Epoch 41  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 23s 235ms/step - accuracy: 0.4235 - loss: 0.7849
# Epoch 42  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 21s 213ms/step - accuracy: 0.4236 - loss: 0.7811
# Epoch 43  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 22s 220ms/step - accuracy: 0.4247 - loss: 0.7750
# Epoch 44  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 21s 214ms/step - accuracy: 0.4258 - loss: 0.7667
# Epoch 45  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 22s 223ms/step - accuracy: 0.4266 - loss: 0.7626
# Epoch 46  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 22s 223ms/step - accuracy: 0.4271 - loss: 0.7584
# Epoch 47  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 22s 224ms/step - accuracy: 0.4279 - loss: 0.7524
# Epoch 48  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 22s 225ms/step - accuracy: 0.4287 - loss: 0.7451
# Epoch 49  in a total of 50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 21s 218ms/step - accuracy: 0.4287 - loss: 0.7418
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ### 8. Generate Captions for the image

# %%
def idx_to_word(integer, tokenizer):
    for word, index in tokenizer.word_index.items():
        if index == integer:
            return word
    return None

# %%
def sample_prediction(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds + 1e-10) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    return np.random.choice(len(preds), p=preds)

# %%
def predict_caption(model, image, tokenizer, max_length, temperature=1.0):
    # Add start sequence token
    in_text = 'startseq'

    for _ in range(max_length):
        # Convert text to sequence and pad
        sequence = tokenizer.texts_to_sequences([in_text])[0]
        sequence = pad_sequences([sequence], maxlen=max_length, padding='post')

        # Predict next word probabilities
        preds = model.predict([image, sequence], verbose=0)
        preds = preds[0, len(in_text.split())-1]

        # Apply temperature-based sampling for diversity
        preds = np.log(preds + 1e-10) / temperature
        exp_preds = np.exp(preds)
        preds = exp_preds / np.sum(exp_preds)

        # Sample next word index
        next_index = np.random.choice(len(preds), p=preds)

        # Map predicted index to word
        next_word = idx_to_word(next_index, tokenizer)

        # End if endseq is predicted or invalid word
        if next_word is None or next_word == 'endseq':
            break

        # Append predicted word to sequence
        in_text += ' ' + next_word

    return in_text

# %% [markdown]
# ### 9. Model Validation

# %%
actual, predicted = list(), list()

for key in tqdm(test):
    # get actual caption
    captions = mapping_dic[key]
    # predict the caption for image
    y_pred = predict_caption(model, features[key], tokenizer, max_length)
    # split into words
    actual_captions = [caption.split() for caption in captions]
    y_pred = y_pred.split()
    # append to the list
    actual.append(actual_captions)
    predicted.append(y_pred)
# calcuate BLEU score
print("BLEU-1: %f" % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
print("BLEU-2: %f" % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
# Out:
#   0%|          | 0/699 [00:00<?, ?it/s]
# BLEU-1: 0.458122
# BLEU-2: 0.261972

# %%
# Ends the timer for the training
end_time   = time.perf_counter()
total_time = str(td(seconds= int(end_time - start_time)))
print("The final training time has been: ", total_time)
# Out:
# The final training time has been:  1:18:43

# %% [markdown]
# ## 10. Visualize the Results

# %%
def generate_caption(img_path):
    image = Image.open(img_path)
    captions = mapping_dic[image_id]
    print('---------------------Actual---------------------')
    for caption in captions:
        print(caption)
    # predict the caption
    y_pred = predict_caption(model, features[image_id], tokenizer, max_length)
    print('--------------------Predicted--------------------')
    print(y_pred)
    plt.imshow(image)

# %%
def generate_inference_metrics() :
    list_images_ibericam = glob(os.path.join(path_ibericam, '*.jpg'))
    cont = 0
    total_time_inf = 0
    
    for image_path in list_images_ibericam :
        if cont < 5 :
            start_time_inf = time.perf_counter()
            generate_caption(image_path)
            end_time_inf = time.perf_counter()
            total_time_inf += end_time_inf - start_time_inf
        else :
            break
            
        cont +=1
        total_time_inf = total_time_inf / 5
        print("--------------------------------------------------------------------------------------")
        print("--------------------------------------------------------------------------------------")
        print("The time per instance during the inference is an average of: ", str(td(seconds= int(total_time_inf))))

# %%
generate_inference_metrics()
# Out:
# ---------------------Actual---------------------
# startseq "the cloud base is relatively low indicating the potential for rain. there is a significant presence of medium-level clouds contributing to the overcast conditions and suggesting possible continuous rain or storms. despite the absence of low clouds the high percentage of high clouds indicates changes in weather likely hinting at an approaching front. overall the sky is largely overcast which points towards continuous rain or storm activity." endseq
# --------------------Predicted--------------------
# startseq the sky is dominated by dense low clouds indicating heavy rain with a very low cloud base there is significant presence of high clouds suggesting potential changes in weather while the dense mid level clouds further supports the likelihood of continuous rain or storms overall the nearly complete cloud coverage indicates continuous rain possibly associated with cyclonic activity
# --------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------
# The time per instance during the inference is an average of:  0:00:00
# ---------------------Actual---------------------
# startseq "the cloud base is relatively low indicating the potential for rain. there is a significant presence of medium-level clouds contributing to the overcast conditions and suggesting possible continuous rain or storms. despite the absence of low clouds the high percentage of high clouds indicates changes in weather likely hinting at an approaching front. overall the sky is largely overcast which points towards continuous rain or storm activity." endseq
# --------------------Predicted--------------------
# startseq the low altitude of the clouds indicates the potential for rain with moderate high cloud presence fair weather is likely potentially associated with an anticyclone the moderate amount of low clouds suggests some possibility of light showers while the minimal medium cloud presence points to stable conditions for now however the complete overcast sky with dense medium clouds points to continuous rain or stormy weather
# --------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------
# The time per instance during the inference is an average of:  0:00:01
# ---------------------Actual---------------------
# startseq "the cloud base is relatively low indicating the potential for rain. there is a significant presence of medium-level clouds contributing to the overcast conditions and suggesting possible continuous rain or storms. despite the absence of low clouds the high percentage of high clouds indicates changes in weather likely hinting at an approaching front. overall the sky is largely overcast which points towards continuous rain or storm activity." endseq
# --------------------Predicted--------------------
# startseq the extremely low altitude of the clouds indicates a high potential for rain the sky is heavily dominated by low dense clouds pointing to overcast conditions with significant rainfall there is minimal high cloud presence which might have limited amounts suggesting that the main weather activity is happening at lower altitudes overall the dense cloud coverage points to continuous rain or possibly a cyclone
# --------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------
# The time per instance during the inference is an average of:  0:00:01
# ---------------------Actual---------------------
# startseq "the cloud base is relatively low indicating the potential for rain. there is a significant presence of medium-level clouds contributing to the overcast conditions and suggesting possible continuous rain or storms. despite the absence of low clouds the high percentage of high clouds indicates changes in weather likely hinting at an approaching front. overall the sky is largely overcast which points towards continuous rain or storm activity." endseq
# --------------------Predicted--------------------
# startseq the clouds are at a low altitude indicating a high potential for rain high cloud presence is moderate suggesting fair weather but with some incoming changes the significant presence of medium clouds points toward potential light rain with a mostly cloudy sky overall the conditions point towards overcast conditions with potential light precipitation leaning towards moderate precipitation
# --------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------
# The time per instance during the inference is an average of:  0:00:00
# ---------------------Actual---------------------
# startseq "the cloud base is relatively low indicating the potential for rain. there is a significant presence of medium-level clouds contributing to the overcast conditions and suggesting possible continuous rain or storms. despite the absence of low clouds the high percentage of high clouds indicates changes in weather likely hinting at an approaching front. overall the sky is largely overcast which points towards continuous rain or storm activity." endseq
# --------------------Predicted--------------------
# startseq the cloud base is very low indicating a strong potential for rain high cloud cover is dense suggesting significant weather changes the presence of moderate mid level clouds adds to the overcast conditions but not enough to the overall overcast this setup is indicative of continuous rain or a cyclone
# --------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------
# The time per instance during the inference is an average of:  0:00:00
